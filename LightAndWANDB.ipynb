# %%
# !git pull
# Out:
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 4), reused 6 (delta 4), pack-reused 0
# Unpacking objects: 100% (6/6), 798 bytes | 266.00 KiB/s, done.
# From https://github.com/Krost006/Machine_Learning
#    22f7f93..398a47a  main       -> origin/main
# Updating 22f7f93..398a47a
# Fast-forward
#  first/imports.py  | 1 +
#  first/model.py    | 4 ++++
#  first/training.py | 5 +++--
#  3 files changed, 8 insertions(+), 2 deletions(-)

# %%
#%cd Machine_Learning
# !ls -l
# Out:
# total 52
# drwxr-xr-x 2 root root  4096 Nov  1 11:49 data
# drwxr-xr-x 3 root root  4096 Nov  1 14:04 first
# drwxr-xr-x 3 root root  4096 Nov  1 12:02 lightning_logs
# drwxr-xr-x 3 root root  4096 Nov  1 12:02 new_data
# -rw-r--r-- 1 root root    18 Nov  1 11:49 README.md
# -rw-r--r-- 1 root root 31304 Nov  1 11:49 Untitled1.ipynb

# %%
# !pip install lightning

# %%
# !pip install wandb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.2/243.2 kB 13.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.5 MB/s eta 0:00:00
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=86640af5a1a2951f68b0b54aac13d541537daa18bb33d885060325667f834bfe
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# ...

# %%
# !wandb login 23cc8d77af58d5de2a5571d2e818097831695370
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !python -m first.training
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Validation DataLoader 0:  67% 2530/3750 [00:14<00:07, 173.45it/s]
# Validation DataLoader 0:  67% 2531/3750 [00:14<00:07, 173.43it/s]
# Validation DataLoader 0:  68% 2532/3750 [00:14<00:07, 173.36it/s]
# Validation DataLoader 0:  68% 2533/3750 [00:14<00:07, 173.32it/s]
# Validation DataLoader 0:  68% 2534/3750 [00:14<00:07, 173.29it/s]
# Validation DataLoader 0:  68% 2535/3750 [00:14<00:07, 173.28it/s]
# Validation DataLoader 0:  68% 2536/3750 [00:14<00:07, 173.26it/s]
# Validation DataLoader 0:  68% 2537/3750 [00:14<00:07, 173.25it/s]
# Validation DataLoader 0:  68% 2538/3750 [00:14<00:06, 173.22it/s]
# Validation DataLoader 0:  68% 2539/3750 [00:14<00:06, 173.21it/s]
# Validation DataLoader 0:  68% 2540/3750 [00:14<00:06, 173.20it/s]
# Validation DataLoader 0:  68% 2541/3750 [00:14<00:06, 173.18it/s]
# Validation DataLoader 0:  68% 2542/3750 [00:14<00:06, 173.19it/s]
# ...

# %%
# !cd first
! ls first
# Out:
# dataset_prepare.py  imports.py	__init__.py  model.py  __pycache__  training.py
